# %% [markdown]
# <a href="https://colab.research.google.com/github/16Amena/16Amena/blob/main/python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.palettes import Category20
import pandas as pd
from google.colab import files
uploaded=files.upload()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("environmental_data.csv")
print(df)
column = 'Temperature'
data['angle'] = data[column] / data[column].sum() * 2 * np.pi
data['color'] = Category20[len(data)]
p = figure(height=350, title=f"{column} Distribution", toolbar_location=None, tools="hover", tooltips="@index: @angle", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True),
        end_angle=cumsum('angle'),
        line_color="white",
        fill_color='color',
        legend_field='index',
        source=data)
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None
output_notebook()
show(p)
# Out:
#      <input type="file" id="files-7f56480d-0899-4d81-85c4-a316c60d6307" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f56480d-0899-4d81-85c4-a316c60d6307">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
import pandas as pd
df=pd.read_csv("environmental_data.csv")
print(df)
x=['Temperature','Humidity','Pressure']
y=[df['Temperature'].mean(),df['Humidity'].mean(),df['Pressure'].mean()]
plt.bar(x,y)
plt.show()
import seaborn as sns
sns.set(style="whitegrid")
df_melted = df.melt(var_name='Measurement', value_name='Value', ignore_index=False)
plt.show()
# Out:
#      <input type="file" id="files-c23c36c1-134c-4efb-aa4b-5046c611a388" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c23c36c1-134c-4efb-aa4b-5046c611a388">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
import pandas as pd
data=pd.read_csv("environmental_data.csv")
print(df)
plt.figure(figsize=(10, 6))
for column in data.columns:
    plt.plot(data.index, data[column], label=column, marker='o')
plt.title("Line Graph of Environmental Data", fontsize=14)
plt.xlabel("Index", fontsize=12)
plt.ylabel("Values", fontsize=12)
plt.legend(title="Parameters")
plt.grid(alpha=0.3)
plt.show()
# Out:
#      <input type="file" id="files-229564be-91a1-4b30-9a1d-dd7f9303a6da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-229564be-91a1-4b30-9a1d-dd7f9303a6da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
